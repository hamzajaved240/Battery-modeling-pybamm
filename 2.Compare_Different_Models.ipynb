# %% [markdown]
# <a href="https://colab.research.google.com/github/hamzajaved240/Battery-modeling-pybamm/blob/main/2.Compare_Different_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pybamm
import pybamm # imports the pybamm module
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 53.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 MB 7.7 MB/s eta 0:00:00
# ...

# %%
#Comparing SPM, SPMe, DFN

# %%
models=[
    pybamm.lithium_ion.SPM(),
    pybamm.lithium_ion.SPMe(),
    pybamm.lithium_ion.DFN()
]

# %%
sols=[]
for model in models:
    sim=pybamm.Simulation(model)
    sols.append(sim.solve([0,3600]))

# %%
sols

# %%
pybamm.dynamic_plot(sols)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.01), Output()), _dom_classes=('w…

# %%
pybamm.dynamic_plot(sols,["Negative particle surface concentration"])
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.01), Output()), _dom_classes=('w…
